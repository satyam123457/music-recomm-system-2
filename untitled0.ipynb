# %% [markdown]
# <a href="https://colab.research.google.com/github/satyam123457/music-recomm-system-2/blob/satyam/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import Recommenders as Recommenders
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.manifold import TSNE
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
 
import warnings
warnings.filterwarnings('ignore')

#next line 
song_df_1 = pd.read_csv('triplets_file.csv')
song_df_1.head()
# Out:
#                                     user_id             song_id  listen_count
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995           1.0
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B           2.0
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0           1.0
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D           1.0
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273           1.0

# %%
song_df_2 = pd.read_csv('song_data.csv')
song_df_2.head()
# Out:
#               song_id              title  \
# 0  SOQMMHC12AB0180CB8       Silent Night
# 1  SOVFVAK12A8C1350D9        Tanssi vaan
# 2  SOGTUKN12AB017F4F1  No One Could Ever
# 3  SOBNYVR12A8C13558C      Si Vos Querés
# 4  SOHSBXH12A8C13B0DF   Tangle Of Aspens
#
#                                 release       artist_name    year
# 0                 Monster Ballads X-Mas  Faster Pussy cat  2003.0
# 1                           Karkuteillä  Karkkiautomaatti  1995.0
# 2                                Butter    Hudson Mohawke  2006.0
# 3                               De Culo       Yerba Brava  2003.0
# 4  Rene Ablaze Presents Winter Sessions        Der Mystic     0.0

# %%
# combine both data
song_df = pd.merge(song_df_1, song_df_2.drop_duplicates(['song_id']), on='song_id', how='left')
song_df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995           1.0
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B           2.0
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0           1.0
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D           1.0
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273           1.0
#
#              title              release    artist_name    year
# 0              NaN                  NaN            NaN     NaN
# 1  Entre Dos Aguas  Flamenco Para Niños  Paco De Lucia  1976.0
# 2              NaN                  NaN            NaN     NaN
# 3              NaN                  NaN            NaN     NaN
# 4              NaN                  NaN            NaN     NaN

# %%
tracks = pd.read_csv('tracks_records.csv')
tracks.head()
# Out:
#                                                 name  year  acousticness  \
# 0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...  1921         0.982
# 1                            Clancy Lowered the Boom  1921         0.732
# 2                                          Gati Bali  1921         0.961
# 3                                          Danny Boy  1921         0.967
# 4                        When Irish Eyes Are Smiling  1921         0.957
#
#                                              artists  danceability  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                     ['Dennis Day']         0.819
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                   ['Frank Parker']         0.275
# 4                                     ['Phil Regan']         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# ...

# %%
tracks.shape
# Out:
# (32561, 19)

# %%
tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              32561 non-null  object
#  1   year              32561 non-null  int64
#  2   acousticness      32561 non-null  float64
#  3   artists           32561 non-null  object
#  4   danceability      32560 non-null  float64
#  5   duration_ms       32560 non-null  float64
#  6   energy            32560 non-null  float64
#  7   explicit          32560 non-null  float64
#  8   id                32560 non-null  object
#  9   instrumentalness  32560 non-null  float64
#  10  key               32560 non-null  float64
#  11  liveness          32560 non-null  float64
#  12  loudness          32560 non-null  float64
#  13  valence           32560 non-null  float64
#  14  Unnamed: 14       0 non-null      float64
#  15  popularity        32560 non-null  float64
# ...

# %%
tracks.isnull().sum()
# Out:
# name                    0
# year                    0
# acousticness            0
# artists                 0
# danceability            1
# duration_ms             1
# energy                  1
# explicit                1
# id                      1
# instrumentalness        1
# key                     1
# liveness                1
# loudness                1
# valence                 1
# Unnamed: 14         32561
# popularity              1
# release_date            1
# speechiness             1
# tempo                   1
# dtype: int64

# %%
tracks.dropna(inplace = True)
tracks.isnull().sum().plot.bar()
plt.show()

# %%
tracks = tracks.drop(['id', 'release_date'], axis = 1)

# %%
# creating new feature combining title and artist name
song_df['song'] = song_df['title']+' - '+song_df['artist_name']
song_df.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995           1.0
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B           2.0
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0           1.0
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D           1.0
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273           1.0
#
#              title              release    artist_name    year  \
# 0              NaN                  NaN            NaN     NaN
# 1  Entre Dos Aguas  Flamenco Para Niños  Paco De Lucia  1976.0
# 2              NaN                  NaN            NaN     NaN
# 3              NaN                  NaN            NaN     NaN
# 4              NaN                  NaN            NaN     NaN
#
#                               song
# 0                              NaN
# 1  Entre Dos Aguas - Paco De Lucia
# ...

# %%
# taking top 10k samples for quick results
song_df = song_df.head(10000)

# %%
# cummulative sum of listen count of the songs
song_grouped = song_df.groupby(['song']).agg({'listen_count':'count'}).reset_index()
song_grouped.head()
# Out:
#                                       song  listen_count
# 0  (Anaesthesia) Pulling Teath - Metallica             1
# 1                       A Dream - Cut Copy             4
# 2             A Kind Of Hope - Pilot Speed             1
# 3                 Addicted - Amy Winehouse             2
# 4            All Men Are Liars - Nick Lowe             3

# %%
grouped_sum = song_grouped['listen_count'].sum()
song_grouped['percentage'] = (song_grouped['listen_count'] / grouped_sum ) * 100
song_grouped.sort_values(['listen_count', 'song'], ascending=[0,1])
# Out:
#                                                   song  listen_count  \
# 89   Nothin' On You [feat. Bruno Mars] (Album Versi...            16
# 157       You've Got The Love - Florence + The Machine            10
# 137                             Toxic - Britney Spears             9
# 39      Eenie Meenie - Sean Kingston and Justin Bieber             6
# 20                               Big Me - Foo Fighters             5
# ..                                                 ...           ...
# 151  Wooden Ships (LP Version) - Crosby_ Stills & Nash             1
# 152                              Work It Out - Beyoncé             1
# 154            You Love Me (Album Version) - Devotchka             1
# 156                 You Wanted A Hit - LCD Soundsystem             1
# 158       Your Visits Are Getting Shorter - Bloc Party             1
#
#      percentage
# 89     5.245902
# 157    3.278689
# 137    2.950820
# 39     1.967213
# 20     1.639344
# ..          ...
# ...

# %%
pr = Recommenders.popularity_recommender_py()
pr.create(song_df, 'user_id', 'song')
# display the top 10 popular songs
pr.recommend(song_df['user_id'][5])
# Out:
#                                       user_id  \
# 89   b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 157  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 137  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 39   b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 20   b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 73   b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 94   b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 115  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 1    b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 65   b80344d063b5ccb3212f76538f3d9e43d87dca9e
#
#                                                   song  score  Rank
# 89   Nothin' On You [feat. Bruno Mars] (Album Versi...     16   1.0
# 157       You've Got The Love - Florence + The Machine     10   2.0
# 137                             Toxic - Britney Spears      9   3.0
# 39      Eenie Meenie - Sean Kingston and Justin Bieber      6   4.0
# 20                               Big Me - Foo Fighters      5   5.0
# ...

# %%
ir = Recommenders.item_similarity_recommender_py()
ir.create(song_df, 'user_id', 'song')
user_items = ir.get_user_items(song_df['user_id'][5])
# display user songs history
for user_item in user_items:
    print(user_item)
# Out:
# nan
# Entre Dos Aguas - Paco De Lucia

# %%
# give song recommendation for that user
ir.recommend(song_df['user_id'][5])
# Out:
# No. of unique songs for the user: 2
# no. of unique songs in the training set: 161
# Non zero values in cooccurence_matrix :2
#                                     user_id  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 5  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 6  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 7  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 8  b80344d063b5ccb3212f76538f3d9e43d87dca9e
# 9  b80344d063b5ccb3212f76538f3d9e43d87dca9e
#
#                                                 song  score  rank
# 0                             Toxic - Britney Spears   0.05     1
# 1  Clenching The Fists Of Dissent (Explicit Album...   0.00     2
# 2          Helpless - Crosby_ Stills_ Nash and Young   0.00     3
# 3                 We've Only Just Begun - Carpenters   0.00     4
# ...

# %%
df = pd.read_csv('tracks_records.csv')
df.head(500)
# Out:
#                                                   name  year  acousticness  \
# 0    Piano Concerto No. 3 in D Minor, Op. 30: III. ...  1921         0.982
# 1                              Clancy Lowered the Boom  1921         0.732
# 2                                            Gati Bali  1921         0.961
# 3                                            Danny Boy  1921         0.967
# 4                          When Irish Eyes Are Smiling  1921         0.957
# ..                                                 ...   ...           ...
# 495                      Save Your Sorrow For Tomorrow  1924         0.988
# 496                                         Les ananas  1924         0.993
# 497                      Padre Nuestro - Remasterizado  1924         0.996
# 498                    Melodía de Amor - Remasterizado  1924         0.996
# 499                        Arrepentida - Remasterizado  1924         0.996
#
# ...

# %% [markdown]
# 2nd program initialise

# %%
model = TSNE(n_components = 2, random_state = 0)
tsne_data = model.fit_transform(df.head(500))
plt.figure(figsize = (7, 7))
plt.scatter(tsne_data[:,0], tsne_data[:,1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-d568f0fa71ec> in <module>
#       1 model = TSNE(n_components = 2, random_state = 0)
# ----> 2 tsne_data = model.fit_transform(df.head(500))
#       3 plt.figure(figsize = (7, 7))
#       4 plt.scatter(tsne_data[:,0], tsne_data[:,1])
#       5 plt.show()
#
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_t_sne.py in fit_transform(self, X, y)
#    1117         self._validate_params()
#    1118         self._check_params_vs_input(X)
# -> 1119         embedding = self._fit(X)
#    1120         self.embedding_ = embedding
#    1121         return self.embedding_
#
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_t_sne.py in _fit(self, X, skip_num_points)
#     852
#     853         if self.method == "barnes_hut":
# --> 854             X = self._validate_data(
#     855                 X,
# ...
